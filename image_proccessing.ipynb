# %% [markdown]
# <a href="https://colab.research.google.com/github/yup4280/Image-Processing-Using-Python/blob/main/image_proccessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#import the required python libraries
import numpy as np
import matplotlib.pyplot as plt
from skimage import img_as_uint
from skimage.io import imshow,imread
from skimage.color import rgb2hsv
from skimage.color import rgb2gray

# %%
array_1=np.array([[255,0],[0,255]])
imshow(array_1,cmap='gray');
# Out:
# /tmp/ipython-input-3731417165.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(array_1,cmap='gray');
# /usr/local/lib/python3.12/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
array_2=np.array([[255,0,255],[0,255,0],[255,0,255]])
imshow(array_2,cmap='gray');
# Out:
# /tmp/ipython-input-99294973.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(array_2,cmap='gray');
# /usr/local/lib/python3.12/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
array_spectrum=np.array([np.arange(0,255,17),np.arange(255,0,-17),np.arange(0,255,17),np.arange(255,0,-17)])
fig, ax=plt.subplots(1,2,figsize=(12,4))
ax[0].imshow(array_spectrum,cmap='gray')
ax[0].set_title('Arange Genration')
ax[1].imshow(array_spectrum.T,cmap='gray')
ax[1].set_title('Transpose Genration');

# %%
array_colors=np.array([[[255,0,0],[0,255,0],[0,0,255]]])
imshow(array_colors)
# Out:
# /tmp/ipython-input-1367995777.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(array_colors)
# /usr/local/lib/python3.12/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
doggo=imread('dog.jpg')
imshow(doggo);
# Out:
# /tmp/ipython-input-584017915.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(doggo);

# %%
doggo.shape
# Out:
# (448, 740, 3)

# %%
fig, ax=plt.subplots(1,3,figsize=(6,4),sharey=True)
ax[0].imshow(doggo[:,0:130])
ax[0].set_title('First Split')
ax[1].imshow(doggo[:,130:260])
ax[1].set_title('Second Split')
ax[2].imshow(doggo[:,260:390])
ax[2].set_title('Third Split');

# %%
imshow(doggo[95:250,130:275]);
# Out:
# /tmp/ipython-input-2373757699.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(doggo[95:250,130:275]);

# %%
fig, ax=plt.subplots(1,3,figsize=(12,4),sharey=True)
ax[0].imshow(doggo[:,:,0],cmap='Reds')
ax[0].set_title('Red')
ax[1].imshow(doggo[:,:,1],cmap='Greens')
ax[1].set_title('Green')
ax[2].imshow(doggo[:,:,2],cmap='Blues')
ax[2].set_title('Blue');

# %%
doggo_hsv=rgb2hsv(doggo)
fig, ax=plt.subplots(1,3,figsize=(12,4),sharey=True)
ax[0].imshow(doggo_hsv[:,:,0],cmap='hsv')
ax[0].set_title('Hue')
ax[1].imshow(doggo_hsv[:,:,1],cmap='gray')
ax[1].set_title('Saturation')
ax[2].imshow(doggo_hsv[:,:,2],cmap='gray')
ax[2].set_title('Value');

# %%
doggo_gray=rgb2gray(doggo)
fig, ax=plt.subplots(1,5,figsize=(17,6),sharey=True)
ax[0].imshow(doggo_gray,cmap='gray')
ax[0].set_title('Grayscale Original')
ax[1].imshow(img_as_uint(doggo_gray>0.25),cmap='gray')
ax[1].set_title('Greater than 0.25')
ax[2].imshow(img_as_uint(doggo_gray>0.50),cmap='gray')
ax[2].set_title('Greater than 0.50');
ax[3].imshow(img_as_uint(doggo_gray>0.75),cmap='gray')
ax[3].set_title('Greater than 0.75')
ax[4].imshow(img_as_uint(doggo_gray>np.mean(doggo_gray)),cmap='gray')
ax[4].set_title('Greater than Mean');

# %% [markdown]
# PIL import image

# %%
from PIL import Image
image=Image.open("dog.jpg")

# %%
image.show()

# %%
print(image.size)
print(image.format)
print(image.mode)
# Out:
# (740, 448)
# JPEG
# RGB

# %%
width = 300
height = 200
resized_image=image.resize((width,height))

# %%
left=10
top=10
right=150
bottom=150
cropped_image=image.crop((left,top,right,bottom))

# %%
angle=left
rotated_image=image.rotate(angle)

# %%
image=Image.open("dog.jpg")

# %%
from PIL import ImageDraw
draw=ImageDraw.Draw(image)

# %%
font=ImageFont.truetype("arial.ttf",20)

# %%
text="Hello , World!"
positio

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

#load image
img=cv2.imread('dog.jpg')

#apply unsharp masking
blur=cv2.GaussianBlur(img,(0,0),3)
sharp=cv2.addWeighted(img,1.5,blur,-0.5,0)

#show result
cv2_imshow(sharp)
# Out:
# <PIL.Image.Image image mode=RGB size=740x448>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

#load image
img=cv2.imread('dog.jpg')

#apply high-pass filtering
kernel=np.array([[-1,-1,-1],[-1,9,-1],[-1,-1,-1]])
sharp=cv2.filter2D(img,-1,kernel)

#show result
cv2_imshow(sharp)
# Out:
# <PIL.Image.Image image mode=RGB size=740x448>

# %%
import cv2
import numpy as np
from scipy.signal import convolve2d,fftconvolve
from google.colab.patches import cv2_imshow

#load image
img=cv2.imread('dog.jpg')

#perform deconvolution
kernel=np.ones((5,5))/25
blur=cv2.filter2D(img,-1,kernel)

# Apply deconvolution to each color channel
sharp_channels = []
for i in range(3):
    sharp_channel = fftconvolve(blur[:,:,i], kernel[::-1,::-1], mode='same')
    sharp_channels.append(sharp_channel)

# Stack the channels back together
sharp = np.stack(sharp_channels, axis=2)

#show result
cv2_imshow(sharp.astype(np.uint8)) # Convert to uint8 for displaying
# Out:
# <PIL.Image.Image image mode=RGB size=740x448>
